# %%
import langchain
langchain.__version__
# Out:
# '1.4.0'

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Langchain Version v1
# ### Agents

# %%
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.7-flash"
)

def get_weather(city: str) -> str:
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."


agent = create_agent(
    model=model,
    tools=[get_weather],
    system_prompt="You are a helpful assistant.",
)

agent

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
response = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": "What is the weather like in New York?"
        }
    ]
})

print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'The weather in New York is currently sunny.', 'extras': {'signature': ''}}]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 agent.invoke({"message":"What is the weather in Delhi?"})
#
# File d:\Agent_AI\.venv\lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File d:\Agent_AI\.venv\lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)
#    2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File d:\Agent_AI\.venv\lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File d:\Agent_AI\.venv\lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\Agent_AI\.venv\lib\site-packages\langgraph\_internal\_runnable.py:707, in RunnableSeq.invoke(self, input, config, **kwargs)
#     705     # run in context
#     706     with set_config_context(config, run) as context:
# --> 707         input = context.run(step.invoke, input, config, **kwargs)
#     708 else:
#     709     input = step.invoke(input, config)
#
# File d:\Agent_AI\.venv\lib\site-packages\langgraph\_internal\_runnable.py:447, in RunnableCallable.invoke(self, input, config, **kwargs)
#     445         run_manager.on_chain_end(ret)
#     446 else:
# --> 447     ret = self.func(*args, **kwargs)
#     448 if self.recurse and isinstance(ret, Runnable):
#     449     return ret.invoke(input, config)
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain\agents\factory.py:1483, in create_agent.<locals>.model_node(state, runtime)
#    1481 has_structured_output = initial_response_format is not None
#    1482 if wrap_model_call_handler is None:
# -> 1483     model_response = _execute_model_sync(request)
#    1484     return _build_commands(model_response, has_structured_output=has_structured_output)
#    1486 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain\agents\factory.py:1454, in create_agent.<locals>._execute_model_sync(request)
#    1451 if request.system_message:
#    1452     messages = [request.system_message, *messages]
# -> 1454 output = model_.invoke(messages)
#    1455 if name:
#    1456     output.name = name
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_core\runnables\base.py:6014, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    6007 @override
#    6008 def invoke(
#    6009     self,
#    (...)
#    6012     **kwargs: Any | None,
#    6013 ) -> Output:
# -> 6014     return self.bound.invoke(
#    6015         input,
#    6016         self._merge_configs(config),
#    6017         **{**self.kwargs, **kwargs},
#    6018     )
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_google_genai\chat_models.py:3578, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    3575         msg = "Tools are already defined.code_execution tool can't be defined"
#    3576         raise ValueError(msg)
# -> 3578 return super().invoke(input, config, stop=stop, **kwargs)
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)
#     481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)
#    1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Agent_AI\.venv\lib\site-packages\langchain_google_genai\chat_models.py:4177, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    4164 request = self._prepare_request(
#    4165     messages,
#    4166     stop=stop,
#    (...)
#    4174     **kwargs,
#    4175 )
#    4176 try:
# -> 4177     response: GenerateContentResponse = self.client.models.generate_content(
#    4178         **request,
#    4179     )
#    4180 except ClientError as e:
#    4181     _handle_client_error(e, request)
#
# File d:\Agent_AI\.venv\lib\site-packages\google\genai\models.py:6236, in Models.generate_content(self, model, contents, config)
#    6232 if incompatible_tools_indexes:
#    6233   _extra_utils.log_afc_incompatible_tools_warning(
#    6234       config, incompatible_tools_indexes
#    6235   )
# -> 6236   return self._generate_content(
#    6237       model=model, contents=contents, config=parsed_config
#    6238   )
#    6240 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    6241     parsed_config
#    6242 )
#    6243 logger.info(
#    6244     f'AFC is enabled with max remote calls: {remaining_remote_calls_afc}.'
#    6245 )
#
# File d:\Agent_AI\.venv\lib\site-packages\google\genai\models.py:4683, in Models._generate_content(self, model, contents, config)
#    4681     path = '{model}:generateContent'
#    4682 else:
# -> 4683   request_dict = _GenerateContentParameters_to_mldev(
#    4684       self._api_client, parameter_model, None, parameter_model
#    4685   )
#    4686   request_url_dict = request_dict.get('_url')
#    4687   if request_url_dict:
#
# File d:\Agent_AI\.venv\lib\site-packages\google\genai\models.py:1635, in _GenerateContentParameters_to_mldev(api_client, from_object, parent_object, root_object)
#    1623   setv(
#    1624       to_object,
#    1625       ['_url', 'model'],
#    1626       t.t_model(api_client, getv(from_object, ['model'])),
#    1627   )
#    1629 if getv(from_object, ['contents']) is not None:
#    1630   setv(
#    1631       to_object,
#    1632       ['contents'],
#    1633       [
#    1634           _Content_to_mldev(item, to_object, root_object)
# -> 1635           for item in t.t_contents(getv(from_object, ['contents']))
#    1636       ],
#    1637   )
#    1639 if getv(from_object, ['config']) is not None:
#    1640   setv(
#    1641       to_object,
#    1642       ['generationConfig'],
#    (...)
#    1645       ),
#    1646   )
#
# File d:\Agent_AI\.venv\lib\site-packages\google\genai\_transformers.py:477, in t_contents(contents)
#     471 def t_contents(
#     472     contents: Optional[
#     473         Union[types.ContentListUnion, types.ContentListUnionDict, types.Content]
#     474     ],
#     475 ) -> list[types.Content]:
#     476   if contents is None or (isinstance(contents, list) and not contents):
# --> 477     raise ValueError('contents are required.')
#     478   if not isinstance(contents, list):
#     479     return [t_content(contents)]
#
# ValueError: contents are required.
